# %%
import crocoddyl
import mujoco
import mujoco.viewer
import mim_solvers
import numpy as np
import matplotlib.pyplot as plt
import hppfcl
import time
from os.path import dirname, join, abspath
np.set_printoptions(precision=4, linewidth=180)

import pin_utils, mpc_utils
from Kuka_utils import *
from Kuka_model import *
from Kuka_Mujoco_utils import *
from IRL_solver import IRL_Crocoddyl
import pinocchio as pin
from pinocchio.visualize import MeshcatVisualizer

from mim_robots.pybullet.env import BulletEnvWithGround
from mim_robots.robot_loader import load_bullet_wrapper, load_mujoco_model, get_robot_list, load_pinocchio_wrapper
from mim_robots.robot_list import MiM_Robots
from numpy.linalg import norm, solve
from scipy.spatial.transform import Rotation as R
from scipy.optimize import minimize
from scipy.optimize import Bounds
# Out:
# pybullet build time: Nov 28 2023 23:45:17

# %%
# %run -i 'init.py'

# %%
obs_set = obstacle_set()
# obs_set.add_obs(np.array([0.65, 0.05, 0.5]), l = 0.2, col_r = 0.15)
obs_set.add_obs(np.array([0.65, -0.15, 0.45]), l = 0.15, col_r = 0.15)
# obs_set.add_obs(np.array([0.5, -0.35, 0.4]), l = 0.2, col_r = 0.15)
obs_num = obs_set.obs_num

# %%
# endeff frame translation goal
endeff_frame_id = pin_model.getFrameId("contact")
endeff_joint_id = pin_model.getJointId("contact")
# endeff_translation = pin_data.oMf[endeff_frame_id].translation.copy()
endeff_translation = np.array([0.4,  -0.5,  0.35])

# %%
w_run = {
    'translation': .1,
    'xReg': 0.1,
    'uReg': 0.0001
}

w_term = {
    'translation': 10,
    'xReg': 0.1
}

w_run_bad = {
    'translation': .0,
    'xReg': 0.1,
    'uReg': 0.0001
}

w_term_bad = {
    'translation': 10,
    'xReg': 0.1
}

# w_run_bad = {
#     'xReg': 0.01,
#     'uReg': 0.0,
#     'translation': .0
# }

# w_term_bad = {
#     'xReg': 0.0,
#     'translation': .0    
# }

c=0
for _ in range(obs_set.obs_num): # Adding Obstacle weights
    w_run['collision'+str(c)] = 1000
    w_term['collision'+str(c)] = 1000
    w_run_bad['collision'+str(c)] = 0
    w_term_bad['collision'+str(c)] = 0
    c+=1

w_run = dict(sorted(w_run.items()))
w_term = dict(sorted(w_term.items()))
w_run_bad = dict(sorted(w_run_bad.items()))
w_term_bad = dict(sorted(w_term_bad.items()))

w_run, w_term = normalize_w(w_run, w_term)
w_run_bad, w_term_bad = normalize_w(w_run_bad, w_term_bad)

# %%
dt = 1e-2
T = 150

solver, runningDatas, terminalData = init_robot(robot_simulator, q0, v0, obs_set, endeff_translation, w_run, w_term, dt, T)

Keys_run = solver.problem.runningDatas[0].differential.costs.costs.todict().keys()
Keys_term = solver.problem.terminalData.differential.costs.costs.todict().keys()
nr_run = len(Keys_run); nr_term = len(Keys_term); nr = nr_run + nr_term

xs_init = [x0 for i in range(T+1)]
us_init = solver.problem.quasiStatic(xs_init[:-1])
# Out:
# /home/sarmad/machines-in-motion/my_git/IRL_Kuka/Kuka_utils.py:29: UserWarning: Deprecated member. Use Frame.parentJoint instead.
#   m.frames[pin_model.getFrameId("universe")].parent,
# /home/sarmad/machines-in-motion/my_git/IRL_Kuka/Kuka_utils.py:27: UserWarning: This function has been marked as deprecated and will be removed in a future release.
#   obsObj = pin.GeometryObject("obstacle"+str(num_obs),

# %%
# Solve 
update_solver_weights(solver, T, w_run, w_term)
solver.termination_tolerance = 1e-4
solver.with_callbacks = False
solver.solve(xs_init, us_init, 500)
xs_opt = solver.xs.copy()
us_opt = solver.us.copy()

# %%
update_solver_weights(solver, T, w_run_bad, w_term_bad)
solver.termination_tolerance = 1e-4
solver.with_callbacks = False
solver.solve(xs_init, us_init, 500)
xs_nopt = solver.xs.copy()
us_nopt = solver.us.copy()

# %%
# num_non_opt = 10 # number of noisy non-optimal trajectories
# num_opt = 10 # number of noisy optimal trajectories
# scale_nopt = 1e-3
# xs_non_opt_set = [np.stack(xs_nopt.copy().tolist())]
# us_non_opt_set = [np.stack(us_nopt.copy().tolist())]
# noise_u = np.zeros(shape=(T, nu))
# noise_x = np.zeros(shape=(T+1, nx))
# for i in range(num_non_opt):
#     for j in range(T):
#         noise_u[j,None] = np.random.normal(0.0, scale_nopt, nu)
#         noise_x[j,None] = np.random.normal(0.0, scale_nopt, nx)
#     U = [us_nopt[k]+noise_u[k] for k in range(T)]
#     us_non_opt_set.append(np.stack(U).copy())
#     # X = solver.problem.rollout(U)
#     X = [xs_nopt[k]+noise_x[k] for k in range(T+1)]
#     xs_non_opt_set.append(np.stack(X).copy())

# noise_u = np.zeros(shape=(T, nu))
# noise_x = np.zeros(shape=(T+1, nx))
# xs_opt_set = [np.stack(xs_opt.copy().tolist())]
# us_opt_set = [np.stack(us_opt.copy().tolist())]
# for i in range(num_opt):
#     for j in range(T):
#         noise_u[j,None] = np.random.normal(0.0, scale_nopt, nu)
#         noise_x[j,None] = np.random.normal(0.0, scale_nopt, nx)
        
#     U = [us_opt[k]+noise_u[k] for k in range(T)]
#     us_opt_set.append(np.stack(U).copy())
#     # X = solver.problem.rollout(U)
#     X = [xs_opt[k]+noise_x[k] for k in range(T+1)]
#     xs_opt_set.append(np.stack(X).copy())

# # update_solver_weights(solver, T, w_run_bad, w_term_bad)
# # for x_, u_ in zip(xs_non_opt_set, us_non_opt_set):
# #     # print(get_traj_feature_and_cost(solver, x_, u_, dt)[0])
# #     print(get_traj_feature_and_cost_multiple(solver, x_, u_, dt, 3)[2])

# %%
## IRL Args
irl_args = {
    'solver': solver,
    'w_run': w_run_bad,
    'w_term': w_term_bad,
    'type': 'autoreg', 'irl_iter': 1, 'sqp_iter': 1, 'next_traj': 'optimal', 'lr': 0.05,
    'dt': dt,
    'line_search_steps': 10,
    'use_bad': True, 'xs_nopt': xs_nopt, 'us_nopt': us_nopt,
    'normalize': False,
    'K_set': 5,
    'N_samples': T,
    'use_best': True,
    'Lambda': 0.0,
    'KL_tol': -10.0,
    'max_iter': 300, 'min_iter': 15,
    'compare_desired': True, 'des_run': w_run, 'des_term': w_term,
    'verbose': True
}

# %%
if 'IRL' in globals():
    del(IRL)
IRL = IRL_Crocoddyl(xs_opt, us_opt, irl_args)
IRL.print_info()
# Out:
# IRL Parameters:
# Initial Running Weight:  {'collision0': 0.0, 'translation': 0.0, 'uReg': 1e-05, 'xReg': 0.01}
# Initial Terminal Weight:  {'collision0': 0.0, 'translation': 1.0, 'xReg': 0.01}
# Type:  autoreg
# Set Size:  5
# Sample Size:  150
# Lambda:  0.0
# SQP Iterations:  1
# IRL Max Iteration:  300
# Sample Time:  0.01

# %%
IRL.solve_irl()
last_x = IRL.last_traj[0]; last_u = IRL.last_traj[1]
best_x = IRL.best_traj[0]; best_u = IRL.best_traj[1]
# Out:
# iter: 0, KL_div: 0.000028, KL_des: 0.012809, Opt Div: 0.861502, Cost Diff: -0.107548, Step: 1.000000
# iter: 1, KL_div: 0.000014, KL_des: 0.006972, Opt Div: 0.822688, Cost Diff: -0.146089, Step: 1.000000
# iter: 2, KL_div: 0.000013, KL_des: 0.004759, Opt Div: 0.614480, Cost Diff: -0.187496, Step: 1.000000
# iter: 3, KL_div: 0.000010, KL_des: 0.004968, Opt Div: 0.307748, Cost Diff: -0.230851, Step: 1.000000
# iter: 4, KL_div: -0.000000, KL_des: 0.003729, Opt Div: 0.051152, Cost Diff: -0.260748, Step: 0.000000
# iter: 5, KL_div: 0.000012, KL_des: 0.004328, Opt Div: 0.051152, Cost Diff: -0.274127, Step: 1.000000
# iter: 6, KL_div: 0.000000, KL_des: 0.004543, Opt Div: 0.414742, Cost Diff: -0.294907, Step: 1.000000
# iter: 7, KL_div: 0.000000, KL_des: 0.004746, Opt Div: 0.396136, Cost Diff: -0.289578, Step: 1.000000
# iter: 8, KL_div: 0.000000, KL_des: 0.004741, Opt Div: 0.380011, Cost Diff: -0.284066, Step: 1.000000
# iter: 9, KL_div: 0.000000, KL_des: 0.004721, Opt Div: 0.366103, Cost Diff: -0.278384, Step: 1.000000
# iter: 10, KL_div: 0.000000, KL_des: 0.004700, Opt Div: 0.354181, Cost Diff: -0.272557, Step: 1.000000
# iter: 11, KL_div: 0.000000, KL_des: 0.004677, Opt Div: 0.344038, Cost Diff: -0.266619, Step: 1.000000
# iter: 12, KL_div: 0.000000, KL_des: 0.004651, Opt Div: 0.335489, Cost Diff: -0.260599, Step: 1.000000
# iter: 13, KL_div: 0.000000, KL_des: 0.004620, Opt Div: 0.328373, Cost Diff: -0.254531, Step: 1.000000
# iter: 14, KL_div: 0.000000, KL_des: 0.004583, Opt Div: 0.322544, Cost Diff: -0.248458, Step: 1.000000
# iter: 15, KL_div: 0.000000, KL_des: 0.004540, Opt Div: 0.317871, Cost Diff: -0.242439, Step: 1.000000
# iter: 16, KL_div: 0.000000, KL_des: 0.004489, Opt Div: 0.314238, Cost Diff: -0.236514, Step: 1.000000
# iter: 17, KL_div: 0.000000, KL_des: 0.004429, Opt Div: 0.311542, Cost Diff: -0.230740, Step: 1.000000
# iter: 18, KL_div: 0.000000, KL_des: 0.004362, Opt Div: 0.309689, Cost Diff: -0.225174, Step: 1.000000
# iter: 19, KL_div: 0.000000, KL_des: 0.004285, Opt Div: 0.308595, Cost Diff: -0.219897, Step: 1.000000
# iter: 20, KL_div: 0.000000, KL_des: 0.004252, Opt Div: 0.308186, Cost Diff: -0.218878, Step: 0.062500
# iter: 21, KL_div: 0.000000, KL_des: 0.004208, Opt Div: 0.308181, Cost Diff: -0.218583, Step: 0.062500
# iter: 22, KL_div: 0.000000, KL_des: 0.004183, Opt Div: 0.308179, Cost Diff: -0.218482, Step: 0.015625
# iter: 23, KL_div: 0.000000, KL_des: 0.004179, Opt Div: 0.308179, Cost Diff: -0.218458, Step: 0.003906
# iter: 24, KL_div: 0.000000, KL_des: 0.004177, Opt Div: 0.308179, Cost Diff: -0.218440, Step: 0.003906
# iter: 25, KL_div: 0.000000, KL_des: 0.004177, Opt Div: 0.308179, Cost Diff: -0.218434, Step: 0.000977
# iter: 26, KL_div: 0.000000, KL_des: 0.004176, Opt Div: 0.308179, Cost Diff: -0.218429, Step: 0.000977
# iter: 27, KL_div: -0.000000, KL_des: 0.004176, Opt Div: 0.308179, Cost Diff: -0.218429, Step: 0.000000
# iter: 28, KL_div: 0.000000, KL_des: 0.004122, Opt Div: 0.308179, Cost Diff: -0.214282, Step: 1.000000
# iter: 29, KL_div: 0.000000, KL_des: 0.004068, Opt Div: 0.308472, Cost Diff: -0.209941, Step: 1.000000
# iter: 30, KL_div: 0.000000, KL_des: 0.004014, Opt Div: 0.309311, Cost Diff: -0.205947, Step: 1.000000
# iter: 31, KL_div: 0.000000, KL_des: 0.003961, Opt Div: 0.310642, Cost Diff: -0.202092, Step: 1.000000
# iter: 32, KL_div: 0.000000, KL_des: 0.003909, Opt Div: 0.312417, Cost Diff: -0.198370, Step: 1.000000
# iter: 33, KL_div: 0.000000, KL_des: 0.003857, Opt Div: 0.314590, Cost Diff: -0.194776, Step: 1.000000
# iter: 34, KL_div: 0.000000, KL_des: 0.003805, Opt Div: 0.317121, Cost Diff: -0.191305, Step: 1.000000
# iter: 35, KL_div: 0.000000, KL_des: 0.003753, Opt Div: 0.319974, Cost Diff: -0.187951, Step: 1.000000
# iter: 36, KL_div: 0.000000, KL_des: 0.003702, Opt Div: 0.323117, Cost Diff: -0.184711, Step: 1.000000
# iter: 37, KL_div: 0.000000, KL_des: 0.003652, Opt Div: 0.326518, Cost Diff: -0.181580, Step: 1.000000
# iter: 38, KL_div: 0.000000, KL_des: 0.003602, Opt Div: 0.330151, Cost Diff: -0.178552, Step: 1.000000
# iter: 39, KL_div: 0.000000, KL_des: 0.003552, Opt Div: 0.333992, Cost Diff: -0.175625, Step: 1.000000
# iter: 40, KL_div: 0.000000, KL_des: 0.003502, Opt Div: 0.338016, Cost Diff: -0.172793, Step: 1.000000
# iter: 41, KL_div: 0.000000, KL_des: 0.003453, Opt Div: 0.342205, Cost Diff: -0.170053, Step: 1.000000
# iter: 42, KL_div: 0.000000, KL_des: 0.003405, Opt Div: 0.346540, Cost Diff: -0.167402, Step: 1.000000
# iter: 43, KL_div: 0.000000, KL_des: 0.003357, Opt Div: 0.351003, Cost Diff: -0.164835, Step: 1.000000
# iter: 44, KL_div: 0.000000, KL_des: 0.003309, Opt Div: 0.355579, Cost Diff: -0.162350, Step: 1.000000
# iter: 45, KL_div: 0.000000, KL_des: 0.003261, Opt Div: 0.360255, Cost Diff: -0.159943, Step: 1.000000
# iter: 46, KL_div: 0.000000, KL_des: 0.003215, Opt Div: 0.365016, Cost Diff: -0.157611, Step: 1.000000
# iter: 47, KL_div: 0.000000, KL_des: 0.003168, Opt Div: 0.369852, Cost Diff: -0.155351, Step: 1.000000
# iter: 48, KL_div: 0.000000, KL_des: 0.003122, Opt Div: 0.374752, Cost Diff: -0.153161, Step: 1.000000
# iter: 49, KL_div: 0.000000, KL_des: 0.003076, Opt Div: 0.379706, Cost Diff: -0.151037, Step: 1.000000
# iter: 50, KL_div: 0.000000, KL_des: 0.003031, Opt Div: 0.384705, Cost Diff: -0.148977, Step: 1.000000
# iter: 51, KL_div: 0.000000, KL_des: 0.002985, Opt Div: 0.389742, Cost Diff: -0.146978, Step: 1.000000
# iter: 52, KL_div: 0.000000, KL_des: 0.002941, Opt Div: 0.394808, Cost Diff: -0.145039, Step: 1.000000
# iter: 53, KL_div: 0.000000, KL_des: 0.002897, Opt Div: 0.399896, Cost Diff: -0.143157, Step: 1.000000
# iter: 54, KL_div: 0.000000, KL_des: 0.002853, Opt Div: 0.405002, Cost Diff: -0.141329, Step: 1.000000
# iter: 55, KL_div: 0.000000, KL_des: 0.002809, Opt Div: 0.410119, Cost Diff: -0.139554, Step: 1.000000
# iter: 56, KL_div: 0.000000, KL_des: 0.002766, Opt Div: 0.415242, Cost Diff: -0.137830, Step: 1.000000
# iter: 57, KL_div: 0.000000, KL_des: 0.002723, Opt Div: 0.420366, Cost Diff: -0.136155, Step: 1.000000
# iter: 58, KL_div: 0.000000, KL_des: 0.002681, Opt Div: 0.425487, Cost Diff: -0.134527, Step: 1.000000
# iter: 59, KL_div: 0.000000, KL_des: 0.002639, Opt Div: 0.430602, Cost Diff: -0.132945, Step: 1.000000
# iter: 60, KL_div: 0.000000, KL_des: 0.002598, Opt Div: 0.435706, Cost Diff: -0.131406, Step: 1.000000
# iter: 61, KL_div: 0.000000, KL_des: 0.002556, Opt Div: 0.440796, Cost Diff: -0.129909, Step: 1.000000
# iter: 62, KL_div: 0.000000, KL_des: 0.002516, Opt Div: 0.445871, Cost Diff: -0.128453, Step: 1.000000
# iter: 63, KL_div: 0.000000, KL_des: 0.002475, Opt Div: 0.450926, Cost Diff: -0.127037, Step: 1.000000
# iter: 64, KL_div: 0.000000, KL_des: 0.002435, Opt Div: 0.455960, Cost Diff: -0.125658, Step: 1.000000
# iter: 65, KL_div: 0.000000, KL_des: 0.002395, Opt Div: 0.460970, Cost Diff: -0.124316, Step: 1.000000
# iter: 66, KL_div: 0.000000, KL_des: 0.002356, Opt Div: 0.465955, Cost Diff: -0.123009, Step: 1.000000
# iter: 67, KL_div: 0.000000, KL_des: 0.002317, Opt Div: 0.470912, Cost Diff: -0.121736, Step: 1.000000
# iter: 68, KL_div: 0.000000, KL_des: 0.002278, Opt Div: 0.475841, Cost Diff: -0.120497, Step: 1.000000
# iter: 69, KL_div: 0.000000, KL_des: 0.002240, Opt Div: 0.480739, Cost Diff: -0.119289, Step: 1.000000
# iter: 70, KL_div: 0.000000, KL_des: 0.002202, Opt Div: 0.485606, Cost Diff: -0.118111, Step: 1.000000
# iter: 71, KL_div: 0.000000, KL_des: 0.002165, Opt Div: 0.490440, Cost Diff: -0.116964, Step: 1.000000
# iter: 72, KL_div: 0.000000, KL_des: 0.002128, Opt Div: 0.495240, Cost Diff: -0.115845, Step: 1.000000
# iter: 73, KL_div: 0.000000, KL_des: 0.002091, Opt Div: 0.500006, Cost Diff: -0.114754, Step: 1.000000
# iter: 74, KL_div: 0.000000, KL_des: 0.002055, Opt Div: 0.504736, Cost Diff: -0.113691, Step: 1.000000
# iter: 75, KL_div: 0.000000, KL_des: 0.002019, Opt Div: 0.509431, Cost Diff: -0.112653, Step: 1.000000
# iter: 76, KL_div: 0.000000, KL_des: 0.001983, Opt Div: 0.514088, Cost Diff: -0.111640, Step: 1.000000
# iter: 77, KL_div: 0.000000, KL_des: 0.001948, Opt Div: 0.518709, Cost Diff: -0.110652, Step: 1.000000
# iter: 78, KL_div: 0.000000, KL_des: 0.001913, Opt Div: 0.523291, Cost Diff: -0.109687, Step: 1.000000
# iter: 79, KL_div: 0.000000, KL_des: 0.001878, Opt Div: 0.527836, Cost Diff: -0.108746, Step: 1.000000
# iter: 80, KL_div: 0.000000, KL_des: 0.001844, Opt Div: 0.532343, Cost Diff: -0.107826, Step: 1.000000
# iter: 81, KL_div: 0.000000, KL_des: 0.001810, Opt Div: 0.536811, Cost Diff: -0.106928, Step: 1.000000
# iter: 82, KL_div: 0.000000, KL_des: 0.001776, Opt Div: 0.541240, Cost Diff: -0.106051, Step: 1.000000
# iter: 83, KL_div: 0.000000, KL_des: 0.001743, Opt Div: 0.545631, Cost Diff: -0.105194, Step: 1.000000
# iter: 84, KL_div: 0.000000, KL_des: 0.001710, Opt Div: 0.549982, Cost Diff: -0.104357, Step: 1.000000
# iter: 85, KL_div: 0.000000, KL_des: 0.001678, Opt Div: 0.554295, Cost Diff: -0.103538, Step: 1.000000
# iter: 86, KL_div: 0.000000, KL_des: 0.001646, Opt Div: 0.558569, Cost Diff: -0.102739, Step: 1.000000
# iter: 87, KL_div: 0.000000, KL_des: 0.001614, Opt Div: 0.562804, Cost Diff: -0.101957, Step: 1.000000
# iter: 88, KL_div: 0.000000, KL_des: 0.001582, Opt Div: 0.566999, Cost Diff: -0.101192, Step: 1.000000
# iter: 89, KL_div: 0.000000, KL_des: 0.001551, Opt Div: 0.571157, Cost Diff: -0.100444, Step: 1.000000
# iter: 90, KL_div: 0.000000, KL_des: 0.001521, Opt Div: 0.575275, Cost Diff: -0.099713, Step: 1.000000
# iter: 91, KL_div: 0.000000, KL_des: 0.001490, Opt Div: 0.579355, Cost Diff: -0.098998, Step: 1.000000
# iter: 92, KL_div: 0.000000, KL_des: 0.001460, Opt Div: 0.583396, Cost Diff: -0.098298, Step: 1.000000
# iter: 93, KL_div: 0.000000, KL_des: 0.001430, Opt Div: 0.587400, Cost Diff: -0.097613, Step: 1.000000
# iter: 94, KL_div: 0.000000, KL_des: 0.001401, Opt Div: 0.591365, Cost Diff: -0.096942, Step: 1.000000
# iter: 95, KL_div: 0.000000, KL_des: 0.001372, Opt Div: 0.595293, Cost Diff: -0.096286, Step: 1.000000
# iter: 96, KL_div: 0.000000, KL_des: 0.001343, Opt Div: 0.599183, Cost Diff: -0.095644, Step: 1.000000
# iter: 97, KL_div: 0.000000, KL_des: 0.001315, Opt Div: 0.603036, Cost Diff: -0.095014, Step: 1.000000
# iter: 98, KL_div: 0.000000, KL_des: 0.001287, Opt Div: 0.606851, Cost Diff: -0.094398, Step: 1.000000
# iter: 99, KL_div: 0.000000, KL_des: 0.001259, Opt Div: 0.610631, Cost Diff: -0.093795, Step: 1.000000
# iter: 100, KL_div: 0.000000, KL_des: 0.001232, Opt Div: 0.614373, Cost Diff: -0.093204, Step: 1.000000
# iter: 101, KL_div: 0.000000, KL_des: 0.001205, Opt Div: 0.618080, Cost Diff: -0.092625, Step: 1.000000
# iter: 102, KL_div: 0.000000, KL_des: 0.001178, Opt Div: 0.621750, Cost Diff: -0.092058, Step: 1.000000
# iter: 103, KL_div: 0.000000, KL_des: 0.001152, Opt Div: 0.625385, Cost Diff: -0.091502, Step: 1.000000
# iter: 104, KL_div: 0.000000, KL_des: 0.001126, Opt Div: 0.628985, Cost Diff: -0.090957, Step: 1.000000
# iter: 105, KL_div: 0.000000, KL_des: 0.001100, Opt Div: 0.632550, Cost Diff: -0.090423, Step: 1.000000
# iter: 106, KL_div: 0.000000, KL_des: 0.001075, Opt Div: 0.636080, Cost Diff: -0.089899, Step: 1.000000
# iter: 107, KL_div: 0.000000, KL_des: 0.001050, Opt Div: 0.639576, Cost Diff: -0.089386, Step: 1.000000
# iter: 108, KL_div: 0.000000, KL_des: 0.001025, Opt Div: 0.643038, Cost Diff: -0.088882, Step: 1.000000
# iter: 109, KL_div: 0.000000, KL_des: 0.001001, Opt Div: 0.646466, Cost Diff: -0.088388, Step: 1.000000
# iter: 110, KL_div: 0.000000, KL_des: 0.000977, Opt Div: 0.649862, Cost Diff: -0.087904, Step: 1.000000
# iter: 111, KL_div: 0.000000, KL_des: 0.000953, Opt Div: 0.653224, Cost Diff: -0.087429, Step: 1.000000
# iter: 112, KL_div: 0.000000, KL_des: 0.000930, Opt Div: 0.656553, Cost Diff: -0.086963, Step: 1.000000
# iter: 113, KL_div: 0.000000, KL_des: 0.000907, Opt Div: 0.659851, Cost Diff: -0.086505, Step: 1.000000
# iter: 114, KL_div: 0.000000, KL_des: 0.000884, Opt Div: 0.663116, Cost Diff: -0.086057, Step: 1.000000
# iter: 115, KL_div: 0.000000, KL_des: 0.000862, Opt Div: 0.666350, Cost Diff: -0.085616, Step: 1.000000
# iter: 116, KL_div: 0.000000, KL_des: 0.000840, Opt Div: 0.669552, Cost Diff: -0.085184, Step: 1.000000
# iter: 117, KL_div: 0.000000, KL_des: 0.000818, Opt Div: 0.672724, Cost Diff: -0.084759, Step: 1.000000
# iter: 118, KL_div: 0.000000, KL_des: 0.000797, Opt Div: 0.675865, Cost Diff: -0.084342, Step: 1.000000
# iter: 119, KL_div: 0.000000, KL_des: 0.000775, Opt Div: 0.678976, Cost Diff: -0.083933, Step: 1.000000
# iter: 120, KL_div: 0.000000, KL_des: 0.000755, Opt Div: 0.682057, Cost Diff: -0.083531, Step: 1.000000
# iter: 121, KL_div: 0.000000, KL_des: 0.000737, Opt Div: 0.685108, Cost Diff: -0.082874, Step: 1.000000
# iter: 122, KL_div: 0.000000, KL_des: 0.000725, Opt Div: 0.688115, Cost Diff: -0.081798, Step: 1.000000
# iter: 123, KL_div: 0.000000, KL_des: 0.000712, Opt Div: 0.691077, Cost Diff: -0.080734, Step: 1.000000
# iter: 124, KL_div: 0.000000, KL_des: 0.000700, Opt Div: 0.694039, Cost Diff: -0.079686, Step: 1.000000
# iter: 125, KL_div: 0.000000, KL_des: 0.000688, Opt Div: 0.697000, Cost Diff: -0.078652, Step: 1.000000
# iter: 126, KL_div: 0.000000, KL_des: 0.000677, Opt Div: 0.699959, Cost Diff: -0.077634, Step: 1.000000
# iter: 127, KL_div: 0.000000, KL_des: 0.000665, Opt Div: 0.702917, Cost Diff: -0.076631, Step: 1.000000
# iter: 128, KL_div: 0.000000, KL_des: 0.000654, Opt Div: 0.705873, Cost Diff: -0.075642, Step: 1.000000
# iter: 129, KL_div: 0.000000, KL_des: 0.000643, Opt Div: 0.708826, Cost Diff: -0.074668, Step: 1.000000
# iter: 130, KL_div: 0.000000, KL_des: 0.000632, Opt Div: 0.711778, Cost Diff: -0.073708, Step: 1.000000
# iter: 131, KL_div: 0.000000, KL_des: 0.000621, Opt Div: 0.714727, Cost Diff: -0.072761, Step: 1.000000
# iter: 132, KL_div: 0.000000, KL_des: 0.000611, Opt Div: 0.717674, Cost Diff: -0.071829, Step: 1.000000
# iter: 133, KL_div: 0.000000, KL_des: 0.000601, Opt Div: 0.720618, Cost Diff: -0.070910, Step: 1.000000
# iter: 134, KL_div: 0.000000, KL_des: 0.000590, Opt Div: 0.723559, Cost Diff: -0.070004, Step: 1.000000
# iter: 135, KL_div: 0.000000, KL_des: 0.000580, Opt Div: 0.726496, Cost Diff: -0.069112, Step: 1.000000
# iter: 136, KL_div: 0.000000, KL_des: 0.000571, Opt Div: 0.729430, Cost Diff: -0.068232, Step: 1.000000
# iter: 137, KL_div: 0.000000, KL_des: 0.000561, Opt Div: 0.732361, Cost Diff: -0.067366, Step: 1.000000
# iter: 138, KL_div: 0.000000, KL_des: 0.000551, Opt Div: 0.735287, Cost Diff: -0.066512, Step: 1.000000
# iter: 139, KL_div: 0.000000, KL_des: 0.000542, Opt Div: 0.738210, Cost Diff: -0.065670, Step: 1.000000
# iter: 140, KL_div: 0.000000, KL_des: 0.000533, Opt Div: 0.741128, Cost Diff: -0.064841, Step: 1.000000
# iter: 141, KL_div: 0.000000, KL_des: 0.000524, Opt Div: 0.744042, Cost Diff: -0.064023, Step: 1.000000
# iter: 142, KL_div: 0.000000, KL_des: 0.000515, Opt Div: 0.746951, Cost Diff: -0.063218, Step: 1.000000
# iter: 143, KL_div: 0.000000, KL_des: 0.000506, Opt Div: 0.749856, Cost Diff: -0.062424, Step: 1.000000
# iter: 144, KL_div: 0.000000, KL_des: 0.000498, Opt Div: 0.752755, Cost Diff: -0.061642, Step: 1.000000
# iter: 145, KL_div: 0.000000, KL_des: 0.000489, Opt Div: 0.755649, Cost Diff: -0.060872, Step: 1.000000
# iter: 146, KL_div: 0.000000, KL_des: 0.000481, Opt Div: 0.758538, Cost Diff: -0.060112, Step: 1.000000
# iter: 147, KL_div: 0.000000, KL_des: 0.000473, Opt Div: 0.761421, Cost Diff: -0.059363, Step: 1.000000
# iter: 148, KL_div: 0.000000, KL_des: 0.000465, Opt Div: 0.764298, Cost Diff: -0.058626, Step: 1.000000
# iter: 149, KL_div: 0.000000, KL_des: 0.000457, Opt Div: 0.767170, Cost Diff: -0.057899, Step: 1.000000
# iter: 150, KL_div: 0.000000, KL_des: 0.000449, Opt Div: 0.770035, Cost Diff: -0.057183, Step: 1.000000
# iter: 151, KL_div: 0.000000, KL_des: 0.000441, Opt Div: 0.772894, Cost Diff: -0.056477, Step: 1.000000
# iter: 152, KL_div: 0.000000, KL_des: 0.000434, Opt Div: 0.775746, Cost Diff: -0.055781, Step: 1.000000
# iter: 153, KL_div: 0.000000, KL_des: 0.000426, Opt Div: 0.778592, Cost Diff: -0.055095, Step: 1.000000
# iter: 154, KL_div: 0.000000, KL_des: 0.000419, Opt Div: 0.781430, Cost Diff: -0.054420, Step: 1.000000
# iter: 155, KL_div: 0.000000, KL_des: 0.000412, Opt Div: 0.784262, Cost Diff: -0.053754, Step: 1.000000
# iter: 156, KL_div: 0.000000, KL_des: 0.000405, Opt Div: 0.787086, Cost Diff: -0.053097, Step: 1.000000
# iter: 157, KL_div: 0.000000, KL_des: 0.000398, Opt Div: 0.789903, Cost Diff: -0.052451, Step: 1.000000
# iter: 158, KL_div: 0.000000, KL_des: 0.000391, Opt Div: 0.792712, Cost Diff: -0.051813, Step: 1.000000
# iter: 159, KL_div: 0.000000, KL_des: 0.000385, Opt Div: 0.795514, Cost Diff: -0.051185, Step: 1.000000
# iter: 160, KL_div: 0.000000, KL_des: 0.000378, Opt Div: 0.798308, Cost Diff: -0.050566, Step: 1.000000
# iter: 161, KL_div: 0.000000, KL_des: 0.000372, Opt Div: 0.801093, Cost Diff: -0.049956, Step: 1.000000
# iter: 162, KL_div: 0.000000, KL_des: 0.000365, Opt Div: 0.803870, Cost Diff: -0.049354, Step: 1.000000
# iter: 163, KL_div: 0.000000, KL_des: 0.000359, Opt Div: 0.806639, Cost Diff: -0.048762, Step: 1.000000
# iter: 164, KL_div: 0.000000, KL_des: 0.000353, Opt Div: 0.809399, Cost Diff: -0.048177, Step: 1.000000
# iter: 165, KL_div: 0.000000, KL_des: 0.000347, Opt Div: 0.812150, Cost Diff: -0.047602, Step: 1.000000
# iter: 166, KL_div: 0.000000, KL_des: 0.000341, Opt Div: 0.814893, Cost Diff: -0.047034, Step: 1.000000
# iter: 167, KL_div: 0.000000, KL_des: 0.000335, Opt Div: 0.817626, Cost Diff: -0.046475, Step: 1.000000
# iter: 168, KL_div: 0.000000, KL_des: 0.000330, Opt Div: 0.820350, Cost Diff: -0.045923, Step: 1.000000
# iter: 169, KL_div: 0.000000, KL_des: 0.000324, Opt Div: 0.823065, Cost Diff: -0.045380, Step: 1.000000
# iter: 170, KL_div: 0.000000, KL_des: 0.000318, Opt Div: 0.825770, Cost Diff: -0.044844, Step: 1.000000
# iter: 171, KL_div: 0.000000, KL_des: 0.000313, Opt Div: 0.828465, Cost Diff: -0.044316, Step: 1.000000
# iter: 172, KL_div: 0.000000, KL_des: 0.000308, Opt Div: 0.831150, Cost Diff: -0.043795, Step: 1.000000
# iter: 173, KL_div: 0.000000, KL_des: 0.000302, Opt Div: 0.833826, Cost Diff: -0.043282, Step: 1.000000
# iter: 174, KL_div: 0.000000, KL_des: 0.000297, Opt Div: 0.836491, Cost Diff: -0.042776, Step: 1.000000
# iter: 175, KL_div: 0.000000, KL_des: 0.000292, Opt Div: 0.839146, Cost Diff: -0.042278, Step: 1.000000
# iter: 176, KL_div: 0.000000, KL_des: 0.000287, Opt Div: 0.841790, Cost Diff: -0.041786, Step: 1.000000
# iter: 177, KL_div: 0.000000, KL_des: 0.000282, Opt Div: 0.844424, Cost Diff: -0.041302, Step: 1.000000
# iter: 178, KL_div: 0.000000, KL_des: 0.000277, Opt Div: 0.847047, Cost Diff: -0.040824, Step: 1.000000
# iter: 179, KL_div: 0.000000, KL_des: 0.000273, Opt Div: 0.849659, Cost Diff: -0.040353, Step: 1.000000
# iter: 180, KL_div: 0.000000, KL_des: 0.000268, Opt Div: 0.852260, Cost Diff: -0.039889, Step: 1.000000
# iter: 181, KL_div: 0.000000, KL_des: 0.000263, Opt Div: 0.854850, Cost Diff: -0.039431, Step: 1.000000
# iter: 182, KL_div: 0.000000, KL_des: 0.000259, Opt Div: 0.857428, Cost Diff: -0.038979, Step: 1.000000
# iter: 183, KL_div: 0.000000, KL_des: 0.000254, Opt Div: 0.859995, Cost Diff: -0.038534, Step: 1.000000
# iter: 184, KL_div: 0.000000, KL_des: 0.000250, Opt Div: 0.862551, Cost Diff: -0.038096, Step: 1.000000
# iter: 185, KL_div: 0.000000, KL_des: 0.000246, Opt Div: 0.865095, Cost Diff: -0.037663, Step: 1.000000
# iter: 186, KL_div: 0.000000, KL_des: 0.000242, Opt Div: 0.867627, Cost Diff: -0.037236, Step: 1.000000
# iter: 187, KL_div: 0.000000, KL_des: 0.000238, Opt Div: 0.870146, Cost Diff: -0.036816, Step: 1.000000
# iter: 188, KL_div: 0.000000, KL_des: 0.000233, Opt Div: 0.872654, Cost Diff: -0.036401, Step: 1.000000
# iter: 189, KL_div: 0.000000, KL_des: 0.000229, Opt Div: 0.875150, Cost Diff: -0.035992, Step: 1.000000
# iter: 190, KL_div: 0.000000, KL_des: 0.000226, Opt Div: 0.877633, Cost Diff: -0.035589, Step: 1.000000
# iter: 191, KL_div: 0.000000, KL_des: 0.000222, Opt Div: 0.880104, Cost Diff: -0.035191, Step: 1.000000
# iter: 192, KL_div: 0.000000, KL_des: 0.000218, Opt Div: 0.882562, Cost Diff: -0.034799, Step: 1.000000
# iter: 193, KL_div: 0.000000, KL_des: 0.000214, Opt Div: 0.885007, Cost Diff: -0.034412, Step: 1.000000
# iter: 194, KL_div: 0.000000, KL_des: 0.000210, Opt Div: 0.887440, Cost Diff: -0.034030, Step: 1.000000
# iter: 195, KL_div: 0.000000, KL_des: 0.000207, Opt Div: 0.889860, Cost Diff: -0.033654, Step: 1.000000
# iter: 196, KL_div: 0.000000, KL_des: 0.000203, Opt Div: 0.892266, Cost Diff: -0.033283, Step: 1.000000
# iter: 197, KL_div: 0.000000, KL_des: 0.000200, Opt Div: 0.894660, Cost Diff: -0.032917, Step: 1.000000
# iter: 198, KL_div: 0.000000, KL_des: 0.000196, Opt Div: 0.897040, Cost Diff: -0.032556, Step: 1.000000
# iter: 199, KL_div: 0.000000, KL_des: 0.000193, Opt Div: 0.899407, Cost Diff: -0.032200, Step: 1.000000
# iter: 200, KL_div: 0.000000, KL_des: 0.000190, Opt Div: 0.901760, Cost Diff: -0.031848, Step: 1.000000
# iter: 201, KL_div: 0.000000, KL_des: 0.000186, Opt Div: 0.904100, Cost Diff: -0.031502, Step: 1.000000
# iter: 202, KL_div: 0.000000, KL_des: 0.000183, Opt Div: 0.906426, Cost Diff: -0.031160, Step: 1.000000
# iter: 203, KL_div: 0.000000, KL_des: 0.000180, Opt Div: 0.908738, Cost Diff: -0.030823, Step: 1.000000
# iter: 204, KL_div: 0.000000, KL_des: 0.000177, Opt Div: 0.911036, Cost Diff: -0.030490, Step: 1.000000
# iter: 205, KL_div: 0.000000, KL_des: 0.000174, Opt Div: 0.913321, Cost Diff: -0.030162, Step: 1.000000
# iter: 206, KL_div: 0.000000, KL_des: 0.000171, Opt Div: 0.915591, Cost Diff: -0.029838, Step: 1.000000
# iter: 207, KL_div: 0.000000, KL_des: 0.000168, Opt Div: 0.917847, Cost Diff: -0.029518, Step: 1.000000
# iter: 208, KL_div: 0.000000, KL_des: 0.000165, Opt Div: 0.920089, Cost Diff: -0.029203, Step: 1.000000
# iter: 209, KL_div: 0.000000, KL_des: 0.000162, Opt Div: 0.922316, Cost Diff: -0.028892, Step: 1.000000
# iter: 210, KL_div: 0.000000, KL_des: 0.000159, Opt Div: 0.924529, Cost Diff: -0.028585, Step: 1.000000
# iter: 211, KL_div: 0.000000, KL_des: 0.000157, Opt Div: 0.926727, Cost Diff: -0.028282, Step: 1.000000
# iter: 212, KL_div: 0.000000, KL_des: 0.000154, Opt Div: 0.928911, Cost Diff: -0.027983, Step: 1.000000
# iter: 213, KL_div: 0.000000, KL_des: 0.000151, Opt Div: 0.931080, Cost Diff: -0.027688, Step: 1.000000
# iter: 214, KL_div: 0.000000, KL_des: 0.000149, Opt Div: 0.933234, Cost Diff: -0.027397, Step: 1.000000
# iter: 215, KL_div: 0.000000, KL_des: 0.000146, Opt Div: 0.935373, Cost Diff: -0.027109, Step: 1.000000
# iter: 216, KL_div: 0.000000, KL_des: 0.000144, Opt Div: 0.937497, Cost Diff: -0.026826, Step: 1.000000
# iter: 217, KL_div: 0.000000, KL_des: 0.000141, Opt Div: 0.939606, Cost Diff: -0.026546, Step: 1.000000
# iter: 218, KL_div: 0.000000, KL_des: 0.000139, Opt Div: 0.941700, Cost Diff: -0.026270, Step: 1.000000
# iter: 219, KL_div: 0.000000, KL_des: 0.000136, Opt Div: 0.943779, Cost Diff: -0.025997, Step: 1.000000
# iter: 220, KL_div: 0.000000, KL_des: 0.000134, Opt Div: 0.945843, Cost Diff: -0.025728, Step: 1.000000
# iter: 221, KL_div: 0.000000, KL_des: 0.000132, Opt Div: 0.947891, Cost Diff: -0.025462, Step: 1.000000
# iter: 222, KL_div: 0.000000, KL_des: 0.000129, Opt Div: 0.949923, Cost Diff: -0.025200, Step: 1.000000
# iter: 223, KL_div: 0.000000, KL_des: 0.000127, Opt Div: 0.951940, Cost Diff: -0.024941, Step: 1.000000
# iter: 224, KL_div: 0.000000, KL_des: 0.000125, Opt Div: 0.953942, Cost Diff: -0.024685, Step: 1.000000
# iter: 225, KL_div: 0.000000, KL_des: 0.000123, Opt Div: 0.955928, Cost Diff: -0.024433, Step: 1.000000
# iter: 226, KL_div: 0.000000, KL_des: 0.000121, Opt Div: 0.957898, Cost Diff: -0.024183, Step: 1.000000
# iter: 227, KL_div: 0.000000, KL_des: 0.000119, Opt Div: 0.959852, Cost Diff: -0.023937, Step: 1.000000
# iter: 228, KL_div: 0.000000, KL_des: 0.000117, Opt Div: 0.961791, Cost Diff: -0.023694, Step: 1.000000
# iter: 229, KL_div: 0.000000, KL_des: 0.000115, Opt Div: 0.963713, Cost Diff: -0.023454, Step: 1.000000
# iter: 230, KL_div: 0.000000, KL_des: 0.000113, Opt Div: 0.965620, Cost Diff: -0.023217, Step: 1.000000
# iter: 231, KL_div: 0.000000, KL_des: 0.000111, Opt Div: 0.967510, Cost Diff: -0.022983, Step: 1.000000
# iter: 232, KL_div: 0.000000, KL_des: 0.000109, Opt Div: 0.969385, Cost Diff: -0.022752, Step: 1.000000
# iter: 233, KL_div: 0.000000, KL_des: 0.000107, Opt Div: 0.971243, Cost Diff: -0.022524, Step: 1.000000
# iter: 234, KL_div: 0.000000, KL_des: 0.000105, Opt Div: 0.973085, Cost Diff: -0.022299, Step: 1.000000
# iter: 235, KL_div: 0.000000, KL_des: 0.000103, Opt Div: 0.974911, Cost Diff: -0.022076, Step: 1.000000
# iter: 236, KL_div: 0.000000, KL_des: 0.000101, Opt Div: 0.976720, Cost Diff: -0.021856, Step: 1.000000
# iter: 237, KL_div: 0.000000, KL_des: 0.000100, Opt Div: 0.978513, Cost Diff: -0.021639, Step: 1.000000
# iter: 238, KL_div: 0.000000, KL_des: 0.000098, Opt Div: 0.980290, Cost Diff: -0.021424, Step: 1.000000
# iter: 239, KL_div: 0.000000, KL_des: 0.000096, Opt Div: 0.982050, Cost Diff: -0.021212, Step: 1.000000
# iter: 240, KL_div: 0.000000, KL_des: 0.000095, Opt Div: 0.983793, Cost Diff: -0.021002, Step: 1.000000
# iter: 241, KL_div: 0.000000, KL_des: 0.000093, Opt Div: 0.985520, Cost Diff: -0.020796, Step: 1.000000
# iter: 242, KL_div: 0.000000, KL_des: 0.000091, Opt Div: 0.987230, Cost Diff: -0.020591, Step: 1.000000
# iter: 243, KL_div: 0.000000, KL_des: 0.000090, Opt Div: 0.988924, Cost Diff: -0.020389, Step: 1.000000
# iter: 244, KL_div: 0.000000, KL_des: 0.000088, Opt Div: 0.990601, Cost Diff: -0.020189, Step: 1.000000
# iter: 245, KL_div: 0.000000, KL_des: 0.000087, Opt Div: 0.992261, Cost Diff: -0.019992, Step: 1.000000
# iter: 246, KL_div: 0.000000, KL_des: 0.000085, Opt Div: 0.993905, Cost Diff: -0.019797, Step: 1.000000
# iter: 247, KL_div: 0.000000, KL_des: 0.000084, Opt Div: 0.995531, Cost Diff: -0.019605, Step: 1.000000
# iter: 248, KL_div: 0.000000, KL_des: 0.000082, Opt Div: 0.997141, Cost Diff: -0.019414, Step: 1.000000
# iter: 249, KL_div: 0.000000, KL_des: 0.000081, Opt Div: 0.998733, Cost Diff: -0.019226, Step: 1.000000
# iter: 250, KL_div: 0.000000, KL_des: 0.000079, Opt Div: 1.000309, Cost Diff: -0.019040, Step: 1.000000
# iter: 251, KL_div: 0.000000, KL_des: 0.000078, Opt Div: 1.001868, Cost Diff: -0.018857, Step: 1.000000
# iter: 252, KL_div: 0.000000, KL_des: 0.000077, Opt Div: 1.003409, Cost Diff: -0.018675, Step: 1.000000
# iter: 253, KL_div: 0.000000, KL_des: 0.000075, Opt Div: 1.004934, Cost Diff: -0.018495, Step: 1.000000
# iter: 254, KL_div: 0.000000, KL_des: 0.000074, Opt Div: 1.006442, Cost Diff: -0.018318, Step: 1.000000
# iter: 255, KL_div: 0.000000, KL_des: 0.000073, Opt Div: 1.007932, Cost Diff: -0.018142, Step: 1.000000
# iter: 256, KL_div: 0.000000, KL_des: 0.000071, Opt Div: 1.009405, Cost Diff: -0.017969, Step: 1.000000
# iter: 257, KL_div: 0.000000, KL_des: 0.000070, Opt Div: 1.010861, Cost Diff: -0.017797, Step: 1.000000
# iter: 258, KL_div: 0.000000, KL_des: 0.000069, Opt Div: 1.012300, Cost Diff: -0.017628, Step: 1.000000
# iter: 259, KL_div: 0.000000, KL_des: 0.000068, Opt Div: 1.013721, Cost Diff: -0.017460, Step: 1.000000
# iter: 260, KL_div: 0.000000, KL_des: 0.000067, Opt Div: 1.015126, Cost Diff: -0.017295, Step: 1.000000
# iter: 261, KL_div: 0.000000, KL_des: 0.000065, Opt Div: 1.016513, Cost Diff: -0.017131, Step: 1.000000
# iter: 262, KL_div: 0.000000, KL_des: 0.000064, Opt Div: 1.017882, Cost Diff: -0.016969, Step: 1.000000
# iter: 263, KL_div: 0.000000, KL_des: 0.000063, Opt Div: 1.019234, Cost Diff: -0.016808, Step: 1.000000
# iter: 264, KL_div: 0.000000, KL_des: 0.000062, Opt Div: 1.020569, Cost Diff: -0.016650, Step: 1.000000
# iter: 265, KL_div: 0.000000, KL_des: 0.000061, Opt Div: 1.021887, Cost Diff: -0.016493, Step: 1.000000
# iter: 266, KL_div: 0.000000, KL_des: 0.000060, Opt Div: 1.023187, Cost Diff: -0.016338, Step: 1.000000
# iter: 267, KL_div: 0.000000, KL_des: 0.000059, Opt Div: 1.024469, Cost Diff: -0.016185, Step: 1.000000
# iter: 268, KL_div: 0.000000, KL_des: 0.000058, Opt Div: 1.025735, Cost Diff: -0.016033, Step: 1.000000
# iter: 269, KL_div: 0.000000, KL_des: 0.000057, Opt Div: 1.026982, Cost Diff: -0.015883, Step: 1.000000
# iter: 270, KL_div: 0.000000, KL_des: 0.000056, Opt Div: 1.028212, Cost Diff: -0.015735, Step: 1.000000
# iter: 271, KL_div: 0.000000, KL_des: 0.000055, Opt Div: 1.029425, Cost Diff: -0.015588, Step: 1.000000
# iter: 272, KL_div: 0.000000, KL_des: 0.000054, Opt Div: 1.030620, Cost Diff: -0.015443, Step: 1.000000
# iter: 273, KL_div: 0.000000, KL_des: 0.000053, Opt Div: 1.031798, Cost Diff: -0.015299, Step: 1.000000
# iter: 274, KL_div: 0.000000, KL_des: 0.000052, Opt Div: 1.032958, Cost Diff: -0.015157, Step: 1.000000
# iter: 275, KL_div: 0.000000, KL_des: 0.000051, Opt Div: 1.034100, Cost Diff: -0.015017, Step: 1.000000
# iter: 276, KL_div: 0.000000, KL_des: 0.000050, Opt Div: 1.035225, Cost Diff: -0.014877, Step: 1.000000
# iter: 277, KL_div: 0.000000, KL_des: 0.000049, Opt Div: 1.036333, Cost Diff: -0.014740, Step: 1.000000
# iter: 278, KL_div: 0.000000, KL_des: 0.000049, Opt Div: 1.037422, Cost Diff: -0.014604, Step: 1.000000
# iter: 279, KL_div: 0.000000, KL_des: 0.000048, Opt Div: 1.038495, Cost Diff: -0.014469, Step: 1.000000
# iter: 280, KL_div: 0.000000, KL_des: 0.000047, Opt Div: 1.039549, Cost Diff: -0.014336, Step: 1.000000
# iter: 281, KL_div: 0.000000, KL_des: 0.000046, Opt Div: 1.040586, Cost Diff: -0.014204, Step: 1.000000
# iter: 282, KL_div: 0.000000, KL_des: 0.000045, Opt Div: 1.041605, Cost Diff: -0.014073, Step: 1.000000
# iter: 283, KL_div: 0.000000, KL_des: 0.000044, Opt Div: 1.042607, Cost Diff: -0.013944, Step: 1.000000
# iter: 284, KL_div: 0.000000, KL_des: 0.000044, Opt Div: 1.043591, Cost Diff: -0.013816, Step: 1.000000
# iter: 285, KL_div: 0.000000, KL_des: 0.000043, Opt Div: 1.044557, Cost Diff: -0.013689, Step: 1.000000
# iter: 286, KL_div: 0.000000, KL_des: 0.000042, Opt Div: 1.045506, Cost Diff: -0.013564, Step: 1.000000
# iter: 287, KL_div: 0.000000, KL_des: 0.000041, Opt Div: 1.046437, Cost Diff: -0.013440, Step: 1.000000
# iter: 288, KL_div: 0.000000, KL_des: 0.000041, Opt Div: 1.047351, Cost Diff: -0.013317, Step: 1.000000
# iter: 289, KL_div: 0.000000, KL_des: 0.000040, Opt Div: 1.048246, Cost Diff: -0.013196, Step: 1.000000
# iter: 290, KL_div: 0.000000, KL_des: 0.000039, Opt Div: 1.049125, Cost Diff: -0.013075, Step: 1.000000
# iter: 291, KL_div: 0.000000, KL_des: 0.000039, Opt Div: 1.049985, Cost Diff: -0.012956, Step: 1.000000
# iter: 292, KL_div: 0.000000, KL_des: 0.000038, Opt Div: 1.050828, Cost Diff: -0.012838, Step: 1.000000
# iter: 293, KL_div: 0.000000, KL_des: 0.000037, Opt Div: 1.051653, Cost Diff: -0.012722, Step: 1.000000
# iter: 294, KL_div: 0.000000, KL_des: 0.000037, Opt Div: 1.052461, Cost Diff: -0.012606, Step: 1.000000
# iter: 295, KL_div: 0.000000, KL_des: 0.000036, Opt Div: 1.053251, Cost Diff: -0.012492, Step: 1.000000
# iter: 296, KL_div: 0.000000, KL_des: 0.000035, Opt Div: 1.054023, Cost Diff: -0.012379, Step: 1.000000
# iter: 297, KL_div: 0.000000, KL_des: 0.000035, Opt Div: 1.054778, Cost Diff: -0.012266, Step: 1.000000
# iter: 298, KL_div: 0.000000, KL_des: 0.000034, Opt Div: 1.055515, Cost Diff: -0.012155, Step: 1.000000
# iter: 299, KL_div: 0.000000, KL_des: 0.000033, Opt Div: 1.056234, Cost Diff: -0.012045, Step: 1.000000
# Maximum iteration termination criteria met.

# %%
print('Running')
for i, key in enumerate(IRL.keys_run):
    print(key, ':')
    print('Desired: {:.5f} || Best: {:.5f} || Last: {:.5f}'.format(list(w_run.values())[i],IRL.best_w[0][i],IRL.last_w[0][i]))
    # print('Desired: {:.4f} || Best: {:.4f}'.format(list(w_run.values())[i],IRL.best_w[0][i]))
print()
print('Terminal')
for i, key in enumerate(IRL.keys_term):
    print(key, ':')
    print('Desired: {:.5f} || Best: {:.5f} || Last: {:.5f}'.format(list(w_term.values())[i], IRL.best_w[1][i], IRL.last_w[1][i]))
    # print('Desired: {:.4f} || Best: {:.4f}'.format(list(w_term.values())[i], IRL.best_w[1][i]))
# Out:
# Running
# collision0 :
# Desired: 1.00000 || Best: 0.00805 || Last: 1.00000
# translation :
# Desired: 0.00010 || Best: 0.03912 || Last: 0.01002
# uReg :
# Desired: 0.00000 || Best: 0.00001 || Last: 0.00000
# xReg :
# Desired: 0.00010 || Best: 0.01000 || Last: 0.00208
#
# Terminal
# collision0 :
# Desired: 1.00000 || Best: 0.00000 || Last: 0.00000
# translation :
# Desired: 0.01000 || Best: 1.00000 || Last: 0.22294
# xReg :
# Desired: 0.00010 || Best: 0.01000 || Last: 0.00208

# %%
n = 1
xs_nopt = IRL.Xs[n]
us_nopt = IRL.Us[n]
viewer = init_mujoco(mj_model, mj_data, q0, np.zeros(nq), obs_set, endeff_translation)
time.sleep(4)
# for i in range(IRL.max_iter):
#     run_traj(viewer, mj_model, mj_data, pin_model, pin_data, IRL.Xs[i], IRL.Us[i], dt)
# run_traj(viewer, mj_model, mj_data, pin_model, pin_data, xs_nopt, us_nopt, dt)
# run_traj(viewer, mj_model, mj_data, pin_model, pin_data, xs_opt, us_opt, dt)
# run_traj(viewer, mj_model, mj_data, pin_model, pin_data, best_x, best_u, dt)
run_traj(viewer, mj_model, mj_data, pin_model, pin_data, last_x, last_u, dt)

# %%
# w_irl_run, w_irl_term = IRL.vector_to_dict(IRL.last_w[0], IRL.last_w[1])
print('Last Cost: ', IRL.get_traj_costs(IRL.phis_set[-1], IRL.last_w[0], IRL.last_w[1])[0])
print('Best Cost: ', IRL.get_traj_costs(IRL.phis_set[IRL.best_ind], IRL.best_w[0], IRL.best_w[1])[0])
# Out:
# Last Cost:  0.2445734404698046
# Best Cost:  0.9744562129510465

# %%
cost_set = []
for i in range(len(IRL.Xs)-1):
    dc = IRL.get_traj_costs(IRL.phis_set[i], IRL.ws[i][0], IRL.ws[i][1])[0] - IRL.get_traj_costs(IRL.phis_opt, IRL.ws[i][0], IRL.ws[i][1])[0]
    # print('Cost Diff: ', dc)
    cost_set.append(dc)
plt.plot(cost_set)

# %%
len(IRL.Xs)
# Out:
# 303
